# %% [markdown]
# # XStoryCloze

# %%
# %cd /content/drive/MyDrive/PhD Julen Etxaniz/phd/xglm/XStoryCloze
# Out:
# /content/drive/MyDrive/PhD Julen Etxaniz/phd/xglm/XStoryCloze

# %%
# !pip install datasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 452.9/452.9 KB 9.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.0/213.0 KB 25.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.4/182.4 KB 11.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.0/132.0 KB 18.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 KB 16.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ...

# %%
import datasets

langs = ["en", "ru", "zh", "es", "ar", "hi", "id", "te", "sw", "eu", "my"]

x_story_cloze = {}
for lang in langs:
    x_story_cloze[lang] = datasets.load_dataset('x_story_cloze.py', lang)
# Out:
# WARNING:datasets.builder:Found cached dataset x_story_cloze (/root/.cache/huggingface/datasets/x_story_cloze/en/0.0.0/c429a800100724b26a931751be46fd0e577fcc49adf9c063dd21e385f5be02ff)
# ...
# Extracting data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating eval split: 0 examples [00:00, ? examples/s]
# Dataset x_story_cloze downloaded and prepared to /root/.cache/huggingface/datasets/x_story_cloze/ru/0.0.0/c429a800100724b26a931751be46fd0e577fcc49adf9c063dd21e385f5be02ff. Subsequent calls will reuse this data.
# ...
# Extracting data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating eval split: 0 examples [00:00, ? examples/s]
# Dataset x_story_cloze downloaded and prepared to /root/.cache/huggingface/datasets/x_story_cloze/zh/0.0.0/c429a800100724b26a931751be46fd0e577fcc49adf9c063dd21e385f5be02ff. Subsequent calls will reuse this data.
# ...

# %%
x_story_cloze["eu"]["train"][0]
# Out:
# {'story_id': '138d5bfb-05cc-41e3-bf2c-fa85ebad14e2',
#  'input_sentence_1': 'Etxe nahasi batean hazi zen Rick.',
#  'input_sentence_2': 'Familian ez zuenez inoiz babesik aurkitu, gaizkile-taldeetara jo zuen.',
#  'input_sentence_3': 'Ez zen denbora luze pasa Rick lapurreta batean tiroz jo zuten arte.',
#  'input_sentence_4': 'Gertaera horrek orrialdea pasatzera bultzatu zuen.',
#  'sentence_quiz1': 'Pozik dago orain.',
#  'sentence_quiz2': 'Gaizkile-talde bateko kide egin zen.',
#  'answer_right_ending': 1}
