# %% [markdown]
# # Translation metrics

# %%
import matplotlib.pyplot as plt

def plot_size_df(df, model_sizes, model_names, title):
    dft = df.set_index("lang").T
    dft["size"] = model_sizes
    dft.plot(x="size", marker="o")
    plt.title(title)
    plt.xticks(model_sizes, model_sizes, rotation="vertical");

# %% [markdown]
# ## Zero-shot translation

# %%
import pandas as pd

metrics_df = pd.read_csv("translation_metrics_xstory_cloze_mt.tsv", sep="\t")

# %%
metrics_df
# Out:
#                        model lang   chrf   bleu
# 0    nllb-200-distilled-600M   ru  60.47  40.84
# 1    nllb-200-distilled-600M   zh  52.03  29.96
# 2    nllb-200-distilled-600M   es  66.19  47.72
# 3    nllb-200-distilled-600M   ar  66.37  49.20
# 4    nllb-200-distilled-600M   hi  64.48  44.94
# ..                       ...  ...    ...    ...
# 226            bloomz-7b1-p3   te  17.10   2.36
# 227            bloomz-7b1-p3   sw  17.04   3.26
# 228            bloomz-7b1-p3   eu  19.48   3.69
# 229            bloomz-7b1-p3   my   1.23   0.00
# 230            bloomz-7b1-p3  avg  19.36   4.69
#
# [231 rows x 4 columns]

# %% [markdown]
# ### BLEU

# %%
# plot nllb models
metrics_df[metrics_df["model"].str.startswith("nllb")].pivot(index="lang", columns="model", values="bleu").plot.bar()
# Out:
# <AxesSubplot: xlabel='lang'>

# %%
# plot bloomz models
metrics_df[metrics_df["model"].str.startswith("bloomz")].pivot(index="lang", columns="model", values="bleu").plot.bar()
# Out:
# <AxesSubplot: xlabel='lang'>

# %%
# plot bloom models
metrics_df[metrics_df["model"].str.startswith("bloom-")].pivot(index="lang", columns="model", values="bleu").plot.bar()
# Out:
# <AxesSubplot: xlabel='lang'>

# %%
# plot xglm models
metrics_df[metrics_df["model"].str.startswith("xglm-")].pivot(index="lang", columns="model", values="bleu").plot.bar()
# Out:
# <AxesSubplot: xlabel='lang'>

# %% [markdown]
# ### CHRF++

# %%
# plot nllb models
metrics_df[metrics_df["model"].str.startswith("nllb")].pivot(index="lang", columns="model", values="chrf").plot.bar()
# Out:
# <AxesSubplot: xlabel='lang'>

# %%
# plot bloomz models
metrics_df[metrics_df["model"].str.startswith("bloomz")].pivot(index="lang", columns="model", values="chrf").plot.bar()
# Out:
# <AxesSubplot: xlabel='lang'>

# %%
# plot bloom models
metrics_df[metrics_df["model"].str.startswith("bloom-")].pivot(index="lang", columns="model", values="chrf").plot.bar()
# Out:
# <AxesSubplot: xlabel='lang'>

# %%
# plot xglm models
metrics_df[metrics_df["model"].str.startswith("xglm-")].pivot(index="lang", columns="model", values="chrf").plot.bar()
# Out:
# <AxesSubplot: xlabel='lang'>

# %% [markdown]
# ## Few-shot translation

# %%
import pandas as pd

metrics_df_few_shot = pd.read_csv("translation_metrics_xstory_cloze_mt_few_shot.tsv", sep="\t")

# %%
metrics_df_few_shot
# Out:
#              model lang   chrf   bleu
# 0               7B   ru  60.03  39.61
# 1               7B   zh  48.26  26.38
# 2               7B   es  66.43  47.48
# 3               7B   ar  39.98  18.86
# 4               7B   hi  37.70  16.56
# ..             ...  ...    ...    ...
# 270  bloomz-7b1-p3   te  37.32  16.00
# 271  bloomz-7b1-p3   sw  42.00  21.67
# 272  bloomz-7b1-p3   eu  42.41  20.39
# 273  bloomz-7b1-p3   my   9.71   0.02
# 274  bloomz-7b1-p3  avg  44.42  24.36
#
# [275 rows x 4 columns]

# %% [markdown]
# ### BLEU

# %%
# plot bloomz models
metrics_df_few_shot[metrics_df_few_shot["model"].str.startswith("bloomz")].pivot(index="lang", columns="model", values="bleu").plot.bar()
# Out:
# <AxesSubplot: xlabel='lang'>

# %%
# plot bloom models
metrics_df_few_shot[metrics_df_few_shot["model"].str.startswith("bloom-")].pivot(index="lang", columns="model", values="bleu").plot.bar()
# Out:
# <AxesSubplot: xlabel='lang'>

# %%
# plot xglm models
metrics_df_few_shot[metrics_df_few_shot["model"].str.startswith("xglm-")].pivot(index="lang", columns="model", values="bleu").plot.bar()
# Out:
# <AxesSubplot: xlabel='lang'>

# %% [markdown]
# ### CHRF++

# %%
# plot bloomz models
metrics_df_few_shot[metrics_df_few_shot["model"].str.startswith("bloomz")].pivot(index="lang", columns="model", values="chrf").plot.bar()
# Out:
# <AxesSubplot: xlabel='lang'>

# %%
# plot bloom models
metrics_df_few_shot[metrics_df_few_shot["model"].str.startswith("bloom-")].pivot(index="lang", columns="model", values="chrf").plot.bar()
# Out:
# <AxesSubplot: xlabel='lang'>

# %%
# plot xglm models
metrics_df_few_shot[metrics_df_few_shot["model"].str.startswith("xglm-")].pivot(index="lang", columns="model", values="chrf").plot.bar()
# Out:
# <AxesSubplot: xlabel='lang'>
